# %%
pip install roboflow
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 56.2/56.2 kB 1.5 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 54.5/54.5 kB 1.6 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 58.8/58.8 kB 2.2 MB/s eta 0:00:00
# ...
#   Preparing metadata (setup.py) ... done
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 67.8/67.8 kB 4.1 MB/s eta 0:00:00
# ...
#   Created wheel for wget: filename=wget-3.2-py3-none-any.whl size=9676 sha256=f0a4c7e3895b647852495d9a82bbe2c396206e70b4cb70752ff70e20859b6c7f
#   Stored in directory: /root/.cache/pip/wheels/04/5f/3e/46cc37c5d698415694d83f607f833f83f0149e49b3af9d0f38
# Successfully built wget
# ...
#   Attempting uninstall: pyparsing
#     Found existing installation: pyparsing 3.0.9
#     Uninstalling pyparsing-3.0.9:
#       Successfully uninstalled pyparsing-3.0.9
#   Attempting uninstall: idna
#     Found existing installation: idna 3.4
# ...

# %%
from roboflow import Roboflow
rf = Roboflow(api_key="u0LxJANQIEwdeF4xXrTA")
project = rf.workspace().project("thermal-detection-uklvx")
model = project.version(1).model
# Out:
# loading Roboflow workspace...
# loading Roboflow project...

# %%
from google.colab import files
from IPython.display import Image
import cv2

img = cv2.imread('/content/test2.jpg')
# upload = files.upload()

# %%
from google.colab.patches import cv2_imshow

cv2_imshow(img)
# Out:
# <PIL.Image.Image image mode=RGB size=416x416 at 0x7FB9377E6DF0>

# %%
# infer on a local image
print(model.predict("test2.jpg", confidence=40, overlap=30).json())
# Out:
# {'predictions': [{'x': 119.0, 'y': 306.0, 'width': 76.0, 'height': 86.0, 'confidence': 0.93478924036026, 'class': 'Car', 'image_path': 'test2.jpg', 'prediction_type': 'ObjectDetectionModel'}, {'x': 67.5, 'y': 344.0, 'width': 133.0, 'height': 144.0, 'confidence': 0.9229135513305664, 'class': 'Car', 'image_path': 'test2.jpg', 'prediction_type': 'ObjectDetectionModel'}, {'x': 278.5, 'y': 329.5, 'width': 147.0, 'height': 123.0, 'confidence': 0.8804840445518494, 'class': 'Car', 'image_path': 'test2.jpg', 'prediction_type': 'ObjectDetectionModel'}], 'image': {'width': '416', 'height': '416'}}

# %%
# visualize your prediction
model.predict("test2.jpg", confidence=40, overlap=30).save("/content/prediction.jpg")

# %%
pred=cv2.imread('/content/prediction.jpg')
cv2_imshow(pred)
# Out:
# <PIL.Image.Image image mode=RGB size=416x416 at 0x7FB937703370>

# %%
Image('prediction.jpg')
